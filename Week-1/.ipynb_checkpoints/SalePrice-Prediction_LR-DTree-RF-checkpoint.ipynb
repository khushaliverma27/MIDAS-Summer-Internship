# %% [markdown]
# # Predicting the Sale Price: Linear Regression

# %% [markdown]
# ## 0. Importing Libraries and Loading Datasets

# %% [markdown]
# ### 0.1 Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import math
import seaborn as sns

from scipy.stats import norm
from scipy import stats

from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor

import warnings 
warnings.filterwarnings('ignore')
plt.style.use('ggplot')

# %% [markdown]
# ### 0.2 Loading the Datasets

# %%
train_df = pd.read_csv(r'.\LR\train.csv')
test_df = pd.read_csv(r'.\LR\test.csv')

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      6    2010        WD         Normal
# 1   12500      6    2010        WD         Normal
# 2       0      3    2010        WD         Normal
# 3       0      6    2010        WD         Normal
# 4       0      1    2010        WD         Normal
#
# [5 rows x 80 columns]

# %% [markdown]
# ## 1. Exploratory Data Analysis

# %% [markdown]
# ### 1.1 Understanding the Datasets

# %%
train_df.shape
# Out:
# (1460, 81)

# %%
test_df.shape
# Out:
# (1459, 80)

# %%
train = train_df.copy()
test = test_df.copy()

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
test.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000  ...
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704  ...
# std       1.113740    30.390071     21.130467   177.625900   455.268042  ...
# min       1.000000  1879.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1953.000000   1963.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1992.000000     0.000000   350.500000  ...
# 75%       6.000000  2001.000000   2004.000000   164.000000   753.500000  ...
# max       9.000000  2010.000000   2010.000000  1290.000000  4010.000000  ...
#
#         GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count  1458.000000  1459.000000  1459.000000    1459.000000  1459.000000
# mean    472.768861    93.174777    48.313914      24.243317     1.794380
# std     217.048611   127.744882    68.883364      67.227765    20.207842
# min       0.000000     0.000000     0.000000       0.000000     0.000000
# 25%     318.000000     0.000000     0.000000       0.000000     0.000000
# 50%     480.000000     0.000000    28.000000       0.000000     0.000000
# 75%     576.000000   168.000000    72.000000       0.000000     0.000000
# max    1488.000000  1424.000000   742.000000    1012.000000   360.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold
# count  1459.000000  1459.000000   1459.000000  1459.000000  1459.000000
# mean     17.064428     1.744345     58.167923     6.104181  2007.769705
# std      56.609763    30.491646    630.806978     2.722432     1.301740
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     4.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     576.000000   800.000000  17000.000000    12.000000  2010.000000
#
# [8 rows x 37 columns]

# %% [markdown]
# #### What are the various columns (or features) of the dataset?

# %%
print(list(train.columns))
# Out:
# ['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice']

# %% [markdown]
# #### Are there any Missing (NaN) Values?

# %%
sns.heatmap(train.isnull(),yticklabels=False, cmap='plasma')

# %%
train.isnull().sum().sort_values(ascending=False)[0:20]
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageCond        81
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# BsmtExposure      38
# BsmtFinType2      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# Utilities          0
# dtype: int64

# %%
sns.heatmap(test.isnull(),yticklabels=False, cmap='plasma')

# %%
test.isnull().sum().sort_values(ascending=False)[0:20]
# Out:
# PoolQC          1456
# MiscFeature     1408
# Alley           1352
# Fence           1169
# FireplaceQu      730
# LotFrontage      227
# GarageCond        78
# GarageQual        78
# GarageYrBlt       78
# GarageFinish      78
# GarageType        76
# BsmtCond          45
# BsmtQual          44
# BsmtExposure      44
# BsmtFinType1      42
# BsmtFinType2      42
# MasVnrType        16
# MasVnrArea        15
# MSZoning           4
# BsmtHalfBath       2
# dtype: int64

# %% [markdown]
# **Inference**: Clearly, PoolQC, MiscFeature, Alley and Fence comprise of maximum missing values. For the purpose of the model, it is better not to take these features into account. Regarding other features with few or medium number of missing values, we can fill those samples with the mean of that value for all other non-missing samples.

# %% [markdown]
# ### 1.2 Understanding the various Features in Training Data

# %% [markdown]
# #### Distribution of Target Variable: Sale Price

# %%
sns.distplot(train['SalePrice'])
plt.show()

# %%
print("Skewness: %f"%train['SalePrice'].skew())
print("Kurtosis: %f"%train['SalePrice'].kurt())
# Out:
# Skewness: 1.882876
# Kurtosis: 6.536282

# %% [markdown]
# **Inference**: Most Houses are sold between the range of 1,00,000 to 2,00,000. The peak occurs at somewhere less than 1,50,000. Clearly, SalePrice is not normally distributed. Therefore, to make the distribution look better, we log transform it.

# %% [markdown]
# #### Log Transforming SalePrice

# %%
train['SalePriceLog'] = np.log(train['SalePrice'])
sns.distplot(train['SalePriceLog'])
print("Skewness: %f"%train['SalePriceLog'].skew())
print("Kurtosis: %f"%train['SalePriceLog'].kurt())
# Out:
# Skewness: 0.121335
# Kurtosis: 0.809532

# %% [markdown]
# The above distribution looks much more normalized.

# %% [markdown]
# #### Which features are Numerical?

# %%
Numerical = [feature for feature in train.columns if train[feature].dtypes != 'O']
Numerical
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice',
#  'SalePriceLog']

# %%
len(Numerical)
# Out:
# 39

# %% [markdown]
# There are total of 38 features that are numerical in nature, as listed above.

# %%
train[Numerical].head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  OpenPorchSF  EnclosedPorch  \
# 0          2003       196.0         706  ...           61              0
# 1          1976         0.0         978  ...            0              0
# 2          2002       162.0         486  ...           42              0
# 3          1970         0.0         216  ...           35            272
# 4          2000       350.0         655  ...           84              0
#
#    3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SalePrice  \
# 0          0            0         0        0       2    2008     208500
# 1          0            0         0        0       5    2007     181500
# 2          0            0         0        0       9    2008     223500
# 3          0            0         0        0       2    2006     140000
# 4          0            0         0        0      12    2008     250000
#
#    SalePriceLog
# 0     12.247694
# 1     12.109011
# 2     12.317167
# 3     11.849398
# 4     12.429216
#
# [5 rows x 39 columns]

# %% [markdown]
# #### Which features are Non-Numerical (or Categorical)?

# %%
NonNumerical = [feature for feature in train.columns if train[feature].dtypes == 'O']
NonNumerical
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
len(NonNumerical)
# Out:
# 43

# %% [markdown]
# There are total of 43 features that are non-numerical in nature, as listed above.

# %%
train[NonNumerical].head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1  ... GarageType GarageFinish GarageQual GarageCond  \
# 0      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 1      Veenker      Feedr  ...     Attchd          RFn         TA         TA
# 2      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 3      Crawfor       Norm  ...     Detchd          Unf         TA         TA
# 4      NoRidge       Norm  ...     Attchd          RFn         TA         TA
#
#   PavedDrive PoolQC Fence MiscFeature SaleType SaleCondition
# 0          Y    NaN   NaN         NaN       WD        Normal
# 1          Y    NaN   NaN         NaN       WD        Normal
# 2          Y    NaN   NaN         NaN       WD        Normal
# 3          Y    NaN   NaN         NaN       WD       Abnorml
# 4          Y    NaN   NaN         NaN       WD        Normal
#
# [5 rows x 43 columns]

# %% [markdown]
# ### 1.3 Removing Missing Values from Training Data

# %%
combined_data = pd.concat((train, test)).reset_index(drop=True)

# %% [markdown]
# #### From Numerical Features

# %%
numerical_missing = [feature for feature in Numerical if train[feature].isna().sum()>0]
numerical_missing
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
train[numerical_missing].isna().sum()
# Out:
# LotFrontage    259
# MasVnrArea       8
# GarageYrBlt     81
# dtype: int64

# %%
for feature in numerical_missing:
    median_value=combined_data[feature].median()
    train[feature].fillna(median_value,inplace=True)
    
train[numerical_missing].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %% [markdown]
# #### From Categorical Features

# %%
categorical_missing = [feature for feature in NonNumerical if train[feature].isna().sum()>0]
categorical_missing
# Out:
# ['Alley',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
train[categorical_missing].isna().sum()
# Out:
# Alley           1369
# MasVnrType         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
for feature in categorical_missing:
    train[feature] = train[feature].fillna('Unknown')

# %%
train[categorical_missing].isna().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# Electrical      0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
train.isnull().sum().sum()
# Out:
# 0

# %%
combined_data = pd.concat((train, test)).reset_index(drop=True)

# %% [markdown]
# ### 1.4 Removing Missing Values from Test Data

# %% [markdown]
# #### From Numerical Features

# %%
numerical_missing = [feature for feature in Numerical if feature!='SalePrice' and feature!='SalePriceLog' and test[feature].isna().sum()>0]
numerical_missing
# Out:
# ['LotFrontage',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea']

# %%
test[numerical_missing].isna().sum()
# Out:
# LotFrontage     227
# MasVnrArea       15
# BsmtFinSF1        1
# BsmtFinSF2        1
# BsmtUnfSF         1
# TotalBsmtSF       1
# BsmtFullBath      2
# BsmtHalfBath      2
# GarageYrBlt      78
# GarageCars        1
# GarageArea        1
# dtype: int64

# %%
for feature in numerical_missing:
    median_value=combined_data[feature].median()
    test[feature].fillna(median_value,inplace=True)
    
test[numerical_missing].isnull().sum()
# Out:
# LotFrontage     0
# MasVnrArea      0
# BsmtFinSF1      0
# BsmtFinSF2      0
# BsmtUnfSF       0
# TotalBsmtSF     0
# BsmtFullBath    0
# BsmtHalfBath    0
# GarageYrBlt     0
# GarageCars      0
# GarageArea      0
# dtype: int64

# %% [markdown]
# #### From Categorical Features

# %%
categorical_missing = [feature for feature in NonNumerical if test[feature].isna().sum()>0]
categorical_missing
# Out:
# ['MSZoning',
#  'Alley',
#  'Utilities',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType']

# %%
test[categorical_missing].isna().sum()
# Out:
# MSZoning           4
# Alley           1352
# Utilities          2
# Exterior1st        1
# Exterior2nd        1
# MasVnrType        16
# BsmtQual          44
# BsmtCond          45
# BsmtExposure      44
# BsmtFinType1      42
# BsmtFinType2      42
# KitchenQual        1
# Functional         2
# FireplaceQu      730
# GarageType        76
# GarageFinish      78
# GarageQual        78
# GarageCond        78
# PoolQC          1456
# Fence           1169
# MiscFeature     1408
# SaleType           1
# dtype: int64

# %%
for feature in categorical_missing:
    test[feature] = train[feature].fillna('Unknown')

# %%
test[categorical_missing].isna().sum()
# Out:
# MSZoning        0
# Alley           0
# Utilities       0
# Exterior1st     0
# Exterior2nd     0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# KitchenQual     0
# Functional      0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# SaleType        0
# dtype: int64

# %%
test.isnull().sum().sum()
# Out:
# 0

# %%
combined_data = pd.concat((train, test)).reset_index(drop=True)

# %% [markdown]
# ### 1.5 Normalizing Numerical Values

# %% [markdown]
# First, let's see which Numerical Features show a high Skewness.

# %%
for col in Numerical:
    print('{:15}'.format(col), 
          'Skewness: {:05.2f}'.format(train[col].skew()) , '   ' , 'Kurtosis: {:06.2f}'.format(train[col].kurt())  )
# Out:
# Id              Skewness: 00.00     Kurtosis: -01.20
# MSSubClass      Skewness: 01.41     Kurtosis: 001.58
# LotFrontage     Skewness: 02.43     Kurtosis: 021.94
# LotArea         Skewness: 12.21     Kurtosis: 203.24
# OverallQual     Skewness: 00.22     Kurtosis: 000.10
# OverallCond     Skewness: 00.69     Kurtosis: 001.11
# YearBuilt       Skewness: -0.61     Kurtosis: -00.44
# YearRemodAdd    Skewness: -0.50     Kurtosis: -01.27
# MasVnrArea      Skewness: 02.68     Kurtosis: 010.14
# BsmtFinSF1      Skewness: 01.69     Kurtosis: 011.12
# BsmtFinSF2      Skewness: 04.26     Kurtosis: 020.11
# BsmtUnfSF       Skewness: 00.92     Kurtosis: 000.47
# TotalBsmtSF     Skewness: 01.52     Kurtosis: 013.25
# 1stFlrSF        Skewness: 01.38     Kurtosis: 005.75
# 2ndFlrSF        Skewness: 00.81     Kurtosis: -00.55
# LowQualFinSF    Skewness: 09.01     Kurtosis: 083.23
# GrLivArea       Skewness: 01.37     Kurtosis: 004.90
# BsmtFullBath    Skewness: 00.60     Kurtosis: -00.84
# BsmtHalfBath    Skewness: 04.10     Kurtosis: 016.40
# FullBath        Skewness: 00.04     Kurtosis: -00.86
# HalfBath        Skewness: 00.68     Kurtosis: -01.08
# BedroomAbvGr    Skewness: 00.21     Kurtosis: 002.23
# KitchenAbvGr    Skewness: 04.49     Kurtosis: 021.53
# TotRmsAbvGrd    Skewness: 00.68     Kurtosis: 000.88
# Fireplaces      Skewness: 00.65     Kurtosis: -00.22
# GarageYrBlt     Skewness: -0.67     Kurtosis: -00.26
# GarageCars      Skewness: -0.34     Kurtosis: 000.22
# GarageArea      Skewness: 00.18     Kurtosis: 000.92
# WoodDeckSF      Skewness: 01.54     Kurtosis: 002.99
# OpenPorchSF     Skewness: 02.36     Kurtosis: 008.49
# EnclosedPorch   Skewness: 03.09     Kurtosis: 010.43
# 3SsnPorch       Skewness: 10.30     Kurtosis: 123.66
# ScreenPorch     Skewness: 04.12     Kurtosis: 018.44
# PoolArea        Skewness: 14.83     Kurtosis: 223.27
# MiscVal         Skewness: 24.48     Kurtosis: 701.00
# MoSold          Skewness: 00.21     Kurtosis: -00.40
# YrSold          Skewness: 00.10     Kurtosis: -01.19
# SalePrice       Skewness: 01.88     Kurtosis: 006.54
# SalePriceLog    Skewness: 00.12     Kurtosis: 000.81

# %% [markdown]
# We see that there are a lot of features with skewness > 1. However, by intuitiveness, most of them may not even be used in the model. As of now, we Log Transform just 2 of the features, and will do the same for any other feature if required at a later stage.

# %%
sns.distplot(train['GrLivArea'])

# %%
sns.distplot(train['LotArea'])

# %%
for df in [train, test]:
    df['GrLivAreaLog'] = np.log(df['GrLivArea'])
    df['LotAreaLog'] = np.log(df['LotArea'])

# %%
Numerical = [feature for feature in train.columns if train[feature].dtypes != 'O']

# %%
sns.distplot(train['GrLivAreaLog'])

# %%
print("Skewness: %f" % train['GrLivAreaLog'].skew())
print("Kurtosis: %f" % train['GrLivAreaLog'].kurt())
# Out:
# Skewness: -0.006995
# Kurtosis: 0.282603

# %%
sns.distplot(train['LotAreaLog'])

# %%
print("Skewness: %f" % train['LotAreaLog'].skew())
print("Kurtosis: %f" % train['LotAreaLog'].kurt())
# Out:
# Skewness: -0.137994
# Kurtosis: 4.713358

# %% [markdown]
# Clearly, the plot is much ore normalized now after the log transform

# %% [markdown]
# ### 1.3 Correlating Numerical Features with SalePrice

# %% [markdown]
# #### Correlating Numerical Features with the SalePriceLog

# %%
Numerical = [feature for feature in train.columns if train[feature].dtypes != 'O']
nrows = 13
ncols = 3

fig, axs = plt.subplots(nrows, ncols, figsize = (ncols*3.5, nrows*3))

listoffeatures = Numerical
listoffeatures.remove('SalePrice')
listoffeatures.remove('Id')
listoffeatures.remove('LotArea')
listoffeatures.remove('GrLivArea')

for r in range(0, nrows):
    for c in range(0, ncols):
        i = r*ncols + c
        if i <len(listoffeatures):
            temp = listoffeatures[i]
            sns.regplot(train[temp], train['SalePriceLog'], ax = axs[r][c])
            stp = stats.pearsonr(train[temp], train['SalePriceLog'])
            str_title = "r = " + "{0:.2f}".format(stp[0]) + "      " "p = " + "{0:.2f}".format(stp[1])
            axs[r][c].set_title(str_title,fontsize=9)
            
plt.tight_layout()    
plt.show()

# %% [markdown]
# #### Identifying Linear Correlations

# %% [markdown]
# From the above plots, we observe that the following features have a good correlation with the SalePriceLog -
# - OverallQual (0.82)
# - YearBlt (0.59)
# - TotalBsmtSF (0.61)
# - 1stFlrSF (0.60)
# - FullBath (0.59)
# - TotRmsAbvGrd (0.53)
# - GarageCars (0.68)
# - GarageArea (0.65)
# - GrLivAreaLog (0.73)

# %% [markdown]
# A few more features have their correlation between 0.40 to 0.50. We may or may not consider them at a later stage. On the other hand, features with a weak correlation (less than a minimum value) will not be considered while building the model.

# %% [markdown]
# #### Removing Outliers

# %% [markdown]
# Removing points where despite the overall quality being 10, the sale price were lower

# %%
train = train.drop(train[(train['OverallQual']==10) & (train['SalePriceLog']<12.3)].index)

# %% [markdown]
# Removing points where despite the Ground Living Area being higher, the sale price were lower

# %%
train = train.drop(train[(train['GrLivAreaLog']>8.3) & (train['SalePriceLog']<12.5)].index)

# %% [markdown]
# #### Finding Features with Strong Correlation to Target

# %%
corr = train.corr()
corr_abs = corr.abs()
target = 'SalePriceLog'
min_corr_value = 0.4

numcols = len(listoffeatures)
ser_corr = corr_abs.nlargest(numcols, target)[target]

cols_abv_corr_limit = list(ser_corr[ser_corr.values > min_corr_value].index)
cols_bel_corr_limit = list(ser_corr[ser_corr.values <= min_corr_value].index)

# %%
print(ser_corr)
# Out:
# SalePriceLog     1.000000
# SalePrice        0.948395
# OverallQual      0.821404
# GrLivAreaLog     0.737427
# GrLivArea        0.725211
# GarageCars       0.681033
# GarageArea       0.656128
# TotalBsmtSF      0.647563
# 1stFlrSF         0.620500
# FullBath         0.595899
# YearBuilt        0.587043
# YearRemodAdd     0.565992
# TotRmsAbvGrd     0.537702
# GarageYrBlt      0.499311
# Fireplaces       0.491998
# MasVnrArea       0.430569
# LotAreaLog       0.402814
# BsmtFinSF1       0.392283
# LotFrontage      0.350593
# WoodDeckSF       0.334250
# OpenPorchSF      0.325215
# 2ndFlrSF         0.319953
# HalfBath         0.314186
# LotArea          0.260544
# BsmtFullBath     0.237099
# BsmtUnfSF        0.221892
# BedroomAbvGr     0.209036
# EnclosedPorch    0.149029
# KitchenAbvGr     0.147534
# ScreenPorch      0.121245
# PoolArea         0.074338
# MSSubClass       0.073969
# MoSold           0.057064
# 3SsnPorch        0.054914
# LowQualFinSF     0.037951
# YrSold           0.037151
# OverallCond      0.036821
# Name: SalePriceLog, dtype: float64

# %%
print("Numerical Features with Correlation > 0.4")
print(cols_abv_corr_limit)
# Out:
# Numerical Features with Correlation > 0.4
# ['SalePriceLog', 'SalePrice', 'OverallQual', 'GrLivAreaLog', 'GrLivArea', 'GarageCars', 'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'FullBath', 'YearBuilt', 'YearRemodAdd', 'TotRmsAbvGrd', 'GarageYrBlt', 'Fireplaces', 'MasVnrArea', 'LotAreaLog']

# %%
print("Numerical Features with Correlation <= 0.4")
print(cols_bel_corr_limit)
# Out:
# Numerical Features with Correlation <= 0.4
# ['BsmtFinSF1', 'LotFrontage', 'WoodDeckSF', 'OpenPorchSF', '2ndFlrSF', 'HalfBath', 'LotArea', 'BsmtFullBath', 'BsmtUnfSF', 'BedroomAbvGr', 'EnclosedPorch', 'KitchenAbvGr', 'ScreenPorch', 'PoolArea', 'MSSubClass', 'MoSold', '3SsnPorch', 'LowQualFinSF', 'YrSold', 'OverallCond']

# %% [markdown]
# #### Correlation Matrix for Numerical Features
# Let's confirm our findings by a correlation matrix

# %%
nr_c = len(cols_abv_corr_limit)

corr = train.corr()
corr_abs = corr.abs()
cols = corr_abs.nlargest(nr_c, target)[target].index
cm = np.corrcoef(train[cols].values.T)

plt.figure(figsize=(nr_c/2, nr_c/2))
sns.set(font_scale=1.25)
sns.heatmap(cm, linewidths=0, annot=True, square=True, 
            fmt='.2f', annot_kws={'size': 10}, 
            yticklabels=cols.values, xticklabels=cols.values
           )
plt.show()

# %% [markdown]
# ### 1.4 Correlating Categorical Features with SalePrice

# %% [markdown]
# #### List of all Categories in each of the Categorical Features

# %%
NonNumerical = [feature for feature in train.columns if train[feature].dtypes == 'O']
for category in NonNumerical:
    print(train[category].value_counts())
    print()
# Out:
# RL         1149
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64
#
# Pave    1452
# Grvl       6
# Name: Street, dtype: int64
#
# Unknown    1367
# Grvl         50
# Pave         41
# Name: Alley, dtype: int64
#
# Reg    925
# IR1    483
# IR2     41
# IR3      9
# Name: LotShape, dtype: int64
#
# Lvl    1311
# Bnk      61
# HLS      50
# Low      36
# Name: LandContour, dtype: int64
#
# AllPub    1457
# NoSeWa       1
# Name: Utilities, dtype: int64
#
# Inside     1051
# Corner      262
# CulDSac      94
# FR2          47
# FR3           4
# Name: LotConfig, dtype: int64
#
# Gtl    1380
# Mod      65
# Sev      13
# Name: LandSlope, dtype: int64
#
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards     98
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# SWISU       25
# StoneBr     25
# MeadowV     17
# Blmngtn     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64
#
# Norm      1260
# Feedr       80
# Artery      48
# RRAn        26
# PosN        18
# RRAe        11
# PosA         8
# RRNn         5
# RRNe         2
# Name: Condition1, dtype: int64
#
# Norm      1444
# Feedr        6
# Artery       2
# RRNn         2
# PosN         1
# PosA         1
# RRAe         1
# RRAn         1
# Name: Condition2, dtype: int64
#
# 1Fam      1218
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: BldgType, dtype: int64
#
# 1Story    726
# 2Story    443
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      8
# Name: HouseStyle, dtype: int64
#
# Gable      1141
# Hip         284
# Flat         13
# Gambrel      11
# Mansard       7
# Shed          2
# Name: RoofStyle, dtype: int64
#
# CompShg    1433
# Tar&Grv      11
# WdShngl       6
# WdShake       5
# Metal         1
# Roll          1
# Membran       1
# Name: RoofMatl, dtype: int64
#
# VinylSd    515
# HdBoard    222
# MetalSd    220
# Wd Sdng    206
# Plywood    108
# CemntBd     60
# BrkFace     50
# WdShing     26
# Stucco      24
# AsbShng     20
# Stone        2
# BrkComm      2
# ImStucc      1
# CBlock       1
# AsphShn      1
# Name: Exterior1st, dtype: int64
#
# VinylSd    504
# MetalSd    214
# HdBoard    207
# Wd Sdng    197
# Plywood    142
# CmentBd     59
# Wd Shng     38
# Stucco      25
# BrkFace     25
# AsbShng     20
# ImStucc     10
# Brk Cmn      7
# Stone        5
# AsphShn      3
# CBlock       1
# Other        1
# Name: Exterior2nd, dtype: int64
#
# None       864
# BrkFace    445
# Stone      126
# BrkCmn      15
# Unknown      8
# Name: MasVnrType, dtype: int64
#
# TA    906
# Gd    488
# Ex     50
# Fa     14
# Name: ExterQual, dtype: int64
#
# TA    1280
# Gd     146
# Fa      28
# Ex       3
# Po       1
# Name: ExterCond, dtype: int64
#
# PConc     645
# CBlock    634
# BrkTil    146
# Slab       24
# Stone       6
# Wood        3
# Name: Foundation, dtype: int64
#
# TA         649
# Gd         618
# Ex         119
# Unknown     37
# Fa          35
# Name: BsmtQual, dtype: int64
#
# TA         1309
# Gd           65
# Fa           45
# Unknown      37
# Po            2
# Name: BsmtCond, dtype: int64
#
# No         953
# Av         221
# Gd         132
# Mn         114
# Unknown     38
# Name: BsmtExposure, dtype: int64
#
# Unf        430
# GLQ        416
# ALQ        220
# BLQ        148
# Rec        133
# LwQ         74
# Unknown     37
# Name: BsmtFinType1, dtype: int64
#
# Unf        1254
# Rec          54
# LwQ          46
# Unknown      38
# BLQ          33
# ALQ          19
# GLQ          14
# Name: BsmtFinType2, dtype: int64
#
# GasA     1426
# GasW       18
# Grav        7
# Wall        4
# OthW        2
# Floor       1
# Name: Heating, dtype: int64
#
# Ex    739
# TA    428
# Gd    241
# Fa     49
# Po      1
# Name: HeatingQC, dtype: int64
#
# Y    1363
# N      95
# Name: CentralAir, dtype: int64
#
# SBrkr      1332
# FuseA        94
# FuseF        27
# FuseP         3
# Mix           1
# Unknown       1
# Name: Electrical, dtype: int64
#
# TA    735
# Gd    586
# Ex     98
# Fa     39
# Name: KitchenQual, dtype: int64
#
# Typ     1358
# Min2      34
# Min1      31
# Mod       15
# Maj1      14
# Maj2       5
# Sev        1
# Name: Functional, dtype: int64
#
# Unknown    690
# Gd         378
# TA         313
# Fa          33
# Ex          24
# Po          20
# Name: FireplaceQu, dtype: int64
#
# Attchd     869
# Detchd     387
# BuiltIn     87
# Unknown     81
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64
#
# Unf        605
# RFn        422
# Fin        350
# Unknown     81
# Name: GarageFinish, dtype: int64
#
# TA         1309
# Unknown      81
# Fa           48
# Gd           14
# Po            3
# Ex            3
# Name: GarageQual, dtype: int64
#
# TA         1324
# Unknown      81
# Fa           35
# Gd            9
# Po            7
# Ex            2
# Name: GarageCond, dtype: int64
#
# Y    1338
# N      90
# P      30
# Name: PavedDrive, dtype: int64
#
# Unknown    1452
# Gd            2
# Fa            2
# Ex            2
# Name: PoolQC, dtype: int64
#
# Unknown    1177
# MnPrv       157
# GdPrv        59
# GdWo         54
# MnWw         11
# Name: Fence, dtype: int64
#
# Unknown    1404
# Shed         49
# Gar2          2
# Othr          2
# TenC          1
# Name: MiscFeature, dtype: int64
#
# WD       1267
# New       120
# COD        43
# ConLD       9
# ConLw       5
# ConLI       5
# CWD         4
# Oth         3
# Con         2
# Name: SaleType, dtype: int64
#
# Normal     1198
# Partial     123
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: SaleCondition, dtype: int64

# %%
len(NonNumerical)
# Out:
# 43

# %% [markdown]
# #### Correlating Categorical Features with SalePriceLog

# %%
listofcatfeatures = NonNumerical
nrows = 15
ncols = 3

fig, axs = plt.subplots(nrows, ncols, figsize=(ncols*4,nrows*3))

for r in range(0,nrows):
    for c in range(0,ncols):  
        i = r*ncols+c
        if i < len(listofcatfeatures):
            sns.boxplot(x=listofcatfeatures[i], y=target, data=train, ax = axs[r][c])
    
plt.tight_layout()    
plt.show()

# %% [markdown]
# #### Identifying Correlation

# %% [markdown]
# From observation, the following Features seem to have good correlation with the SalePriceLog -
# - MSZoning
# - LotShape
# - Neighborhood
# - HouseStyle
# - Foundation
# - Condition2
# - MasVnrType
# - ExterQual
# - ExterCond
# - BsmtQual
# - CentralAir
# - Electrical
# - KitchenQual
# - SaleType
# - SaleCondition

# %% [markdown]
# However, since their are no 'statistics' tp definitely say which ones are correlated, this turns out to be very subjective. Many other features which have considerably large 'Unknowns' have not been considered.

# %% [markdown]
# #### Listing Categorical Features that show good Correlation

# %%
catg_strong_corr = [ 'MSZoning', 'LotShape', 'Neighborhood', 'HouseStyle', 'Foundation', 'Condition2', 'MasVnrType', 'ExterQual', 'ExterCond', 'BsmtQual','CentralAir', 'Electrical', 'KitchenQual', 'SaleType', 'SaleCondition']

# %%
catg_weak_corr = ['Street', 'Alley', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Condition1',  'BldgType', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature']

# %% [markdown]
# ## 2. Data Wrangling

# %% [markdown]
# In this section, we will drop all features with a low correlation with the SalePrice, transform Categorical Data to Numerical Data and handle multicollinearity amongst features

# %% [markdown]
# ### 2.1 Dropping Features with Low Correlation

# %%
to_drop_numerical = cols_bel_corr_limit
to_drop_categorical = catg_weak_corr

# %%
testId = test['Id']
features_to_drop = ['Id'] + to_drop_numerical + to_drop_categorical

# %%
for df in [train, test]:
    df.drop(features_to_drop, inplace = True, axis = 1)

# %% [markdown]
# ### 2.2 Convert Categorical Data to Numerical Data

# %% [markdown]
# #### Understanding the Categorical Data Distribution
# Here, we make violin plots and cat plots to understand the correlation between the selected categorical features and the SalePriceLog

# %%
for category in categories:
    sns.catplot(x = category, y = target, data= train)
    plt.show()

# %%
categories = catg_strong_corr.copy()

for category in categories:
    sns.violinplot(x = category, y = target, data= train)
    plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(16, 5)
sns.violinplot(x='Neighborhood', y=target, data=train, ax=ax)
plt.xticks(rotation=45)
plt.show()

# %%
for category in categories :
    grp = train.groupby(category)[target].mean()
    print(grp)
# Out:
# MSZoning
# C (all)    11.118259
# FV         12.246616
# RH         11.749840
# RL         12.085939
# RM         11.692893
# Name: SalePriceLog, dtype: float64
# LotShape
# IR1    12.163541
# IR2    12.318450
# IR3    12.230134
# Reg    11.936094
# Name: SalePriceLog, dtype: float64
# Neighborhood
# Blmngtn    12.169416
# Blueste    11.826536
# BrDale     11.547864
# BrkSide    11.679727
# ClearCr    12.239900
# CollgCr    12.163641
# Crawfor    12.206659
# Edwards    11.705322
# Gilbert    12.155803
# IDOTRR     11.446889
# MeadowV    11.474522
# Mitchel    11.933948
# NAmes      11.868045
# NPkVill    11.866477
# NWAmes     12.130609
# NoRidge    12.676000
# NridgHt    12.619411
# OldTown    11.703865
# SWISU      11.838435
# Sawyer     11.811468
# SawyerW    12.090689
# Somerst    12.296495
# StoneBr    12.585486
# Timber     12.363455
# Veenker    12.344176
# Name: SalePriceLog, dtype: float64
# HouseStyle
# 1.5Fin    11.813528
# 1.5Unf    11.595027
# 1Story    11.993683
# 2.5Fin    12.194451
# 2.5Unf    11.908751
# 2Story    12.183263
# SFoyer    11.786479
# SLvl      12.002153
# Name: SalePriceLog, dtype: float64
# Foundation
# BrkTil    11.722528
# CBlock    11.870080
# PConc     12.262306
# Slab      11.532959
# Stone     11.933156
# Wood      12.102479
# Name: SalePriceLog, dtype: float64
# Condition2
# Artery    11.570036
# Feedr     11.670631
# Norm      12.025925
# PosA      12.691580
# PosN      12.860999
# RRAe      12.154779
# RRAn      11.827043
# RRNn      11.435329
# Name: SalePriceLog, dtype: float64
# MasVnrType
# BrkCmn     11.853239
# BrkFace    12.163630
# None       11.892919
# Stone      12.431016
# Unknown    12.325054
# Name: SalePriceLog, dtype: float64
# ExterQual
# Ex    12.792412
# Fa    11.304541
# Gd    12.311282
# TA    11.837985
# Name: SalePriceLog, dtype: float64
# ExterCond
# Ex    12.119727
# Fa    11.455162
# Gd    11.969450
# Po    11.245046
# TA    12.043059
# Name: SalePriceLog, dtype: float64
# BsmtQual
# Ex         12.650235
# Fa         11.617600
# Gd         12.179882
# TA         11.810855
# Unknown    11.529680
# Name: SalePriceLog, dtype: float64
# CentralAir
# N    11.491858
# Y    12.061099
# Name: SalePriceLog, dtype: float64
# Electrical
# FuseA      11.660315
# FuseF      11.539624
# FuseP      11.446808
# Mix        11.112448
# SBrkr      12.061474
# Unknown    12.028739
# Name: SalePriceLog, dtype: float64
# KitchenQual
# Ex    12.645425
# Fa    11.504581
# Gd    12.222337
# TA    11.810592
# Name: SalePriceLog, dtype: float64
# SaleType
# COD      11.827437
# CWD      12.198344
# Con      12.483911
# ConLD    11.773000
# ConLI    12.044878
# ConLw    11.769706
# New      12.466114
# Oth      11.675295
# WD       11.991061
# Name: SalePriceLog, dtype: float64
# SaleCondition
# Abnorml    11.788774
# AdjLand    11.529147
# Alloca     11.914458
# Family     11.869655
# Normal     12.005034
# Partial    12.453861
# Name: SalePriceLog, dtype: float64

# %% [markdown]
# #### Dividing the Categories into Numerical Sub-Categories

# %% [markdown]
# By observation from the previously plotted graphs and mean data, we assign numerical values to sub categories of each Category.

# %%
# Neighborhood
neighborhood_2 = ['Blmngtn', 'ClearCr', 'CollgCr', 'Crawfor', 'Gilbert', 'NWAmes', 'Somerst', 'Timber', 'Veenker']
neighborhood_3 = ['NoRidge', 'NridgHt', 'StoneBr']

# HouseStyle
hs_2 = ['1.5Fin', '1.5Unf', 'SFoyer']
hs_3 = ['1Story', '2.5Fin', '2.5Unf', '2Story', 'SLvl']

# MSZoning
msz_2 = ['RM', 'RH']
msz_3 = ['RL', 'FV']

# Foundation
found_2 = ['BrkTil', 'CBlock', 'Slab', 'Stone']
found_3 = ['PConc', 'Wood']

# Condition2
cond_2 = ['Artery', 'Feeds', 'RRAn', 'RRNn']
cond_3 = ['Norm', 'RRAe']
cond_4 = ['PosA', 'PosN'] 

# SaleType
st_1 = ['Oth']
st_2 = ['CWD', 'ConLD', 'WD', 'ConLW', 'COD']
st_3 = ['New', 'Con', 'ConLI']

# SaleCondition
sc_1 = ['Abnormal']
sc_2 = ['AdjLand', 'Alloca']
sc_3 = ['Family', 'Normal', 'Partial']

# %% [markdown]
# At this point, we decide to drop LotShape, since it doesn't seem to be as dependent on SalePrice, given that all sub-categories have approximately same mean.

# %%
for df in [train, test]:
    df.drop(['LotShape'], inplace = True, axis = 1)

# %% [markdown]
# #### Encoding using the Numerical Subcategories

# %%
for df in [train, test]:
    df['MSZ_num'] = 1
    df.loc[(df['MSZoning'].isin(msz_2)), 'MSZ_num'] = 2
    df.loc[(df['MSZoning'].isin(msz_3)), 'MSZ_num'] = 3
    
    df['Neighborhood_num'] = 1
    df.loc[(df['Neighborhood'].isin(neighborhood_2)), 'Neighborhood_num'] = 2
    df.loc[(df['Neighborhood'].isin(neighborhood_3)), 'Neighborhood_num'] = 3

# %%
var = 'LotFrontage'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))

# %% [markdown]
# **Inference**: Apart from a few outliers, the data is somewhat grouped and might not be a very good feature to include in the model.

# %%
var = 'LotArea'
data = pd.concat([train['SalePrice'], train[var].apply(math.log)], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))

# %% [markdown]
# **Inference**: On mapping the sale price with the log of LotArea, we can definitely observe certain linear patter, except for the few outliers which may be removed later if needed.

# %%
var = 'MasVnrArea'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))

# %% [markdown]
# **Inference**: Has a lot of Missing Values which have been marked as 0. Removing the NaN values (although not a good idea as it lessens the data in hand) could prove helpful.

# %%
var = 'BsmtFinSF1'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))

# %% [markdown]
# **Inference**: Just one outlier, good measure overall, except that there are quite many missing values.

# %%
var = 'BsmtFinSF2'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))

# %% [markdown]
# **Inference**: Quite varied distribution, along with a lot of Missing values.

# %%
var = 'BsmtUnfSF'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))

# %% [markdown]
# **Inference**: Seems like a feasible measure to use in the model.

# %%
var = 'TotalBsmtSF'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))

# %% [markdown]
# **Inference**: Comparitively less Missing Values, a good pattern can be observed - as the Basement Surface Area increases, Sale Prices increases (except for the one outlier that has a low sale price for a large basement surface)

# %%
var = '1stFlrSF'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))

# %% [markdown]
# **Inference**: Another good meaure with an observable increase in sale price with increase in surface area of first floor.

# %%
var = '2ndFlrSF'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))

# %% [markdown]
# **Inference**: Similar to the first floor surface area, good measure with observable pattern.

# %%
var = 'GrLivArea'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))

# %% [markdown]
# **Inference**: Very few outliers, linear pattern observable again.

# %%
var = 'GarageArea'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))

# %% [markdown]
# **Infernce**: Few Missing values seen, otherwise the plot is linearly scattered.

# %%
var = 'WoodDeckSF'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))

# %% [markdown]
# **Inference**: Lot of Missing values, might not be a good feature to include.

# %%
var = 'OpenPorchSF'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))

# %% [markdown]
# **Inference**: Again, a lot of missing values.

# %%
var = 'EnclosedPorch'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))

# %% [markdown]
# **Inference**: A lot more missing values, not to be included unless missing values are filled.

# %% [markdown]
# #### Correlating Discrete Numerical Features with SalePrice

# %%
var = 'OverallQual'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(14, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
var = 'OverallCond'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(14, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
var = 'BsmtFullBath'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(14, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
var = 'BsmtHalfBath'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(14, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
var = 'FullBath'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(14, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
var = 'HalfBath'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(14, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
var = 'BedroomAbvGr'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(14, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
var = 'KitchenAbvGr'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(14, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
var = 'TotRmsAbvGrd'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(14, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
var = 'Fireplaces'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(14, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
var = 'GarageCars'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(14, 8))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %% [markdown]
# ### 1.4 Understanding Categorical Features

# %%
Categorical = [feature for feature in train.columns if train[feature].dtypes=='O']
Categorical

# %%
len(Categorical)

# %%
train[Categorical].head()

# %% [markdown]
# #### Mapping the different categories in each of these features

# %%
for feature in Categorical:
    print(feature, train[feature].unique())
    print()

# %%
for feature in Categorical:
    data=train_df.copy()
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()

# %% [markdown]
# ## 2. Feature Engineering and Selection

# %% [markdown]
# #### Combining the train and test data for Feature Engineering

# %%
target_feature = train.SalePrice.values
combined_data = pd.concat((train, test)).reset_index(drop=True)
combined_data.drop(['SalePrice','Id'], axis=1, inplace=True)

# %% [markdown]
# ### 2.2 Feature Selection

# %%
corrmat = train.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
k = 9
cols = corrmat.nlargest(k, 'SalePrice')['SalePrice'].index
f, ax = plt.subplots(figsize=(14, 10))
sns.heatmap(train[cols].corr(), vmax=1, square=True);

# %%
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd']
sns.pairplot(train[cols], size = 8);

# %%
features = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd']

# %% [markdown]
# ### 2.3 Removing Outliers

# %% [markdown]
# #### For GrLivArea

# %%
train = train.drop(train[(train['GrLivArea']>4000) & (train['SalePrice']<300000)].index)

plt.scatter(train['GrLivArea'], train['SalePrice'])
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')
plt.show()

# %% [markdown]
# #### For TotalBsmtSF

# %%
train = train.drop(train[(train['TotalBsmtSF']>5000) & (train['SalePrice']<300000)].index)

plt.scatter(train['TotalBsmtSF'],train['SalePrice'])
plt.xlabel('TotalBsmtSF')
plt.ylabel('SalePrice')
plt.show()

# %% [markdown]
# #### For 1stFlrSF

# %%
train = train.drop(train[(train['1stFlrSF']>5000) & (train['SalePrice']<300000)].index)

plt.scatter(train['1stFlrSF'],train['SalePrice'])
plt.xlabel('1stFlrSF')
plt.ylabel('SalePrice')
plt.show()

# %% [markdown]
# Most Other Features do not have any noticeable Outliers.

# %% [markdown]
# ### 2.4 Unedrstanding Normalities of selected Continuous Numerical Data

# %%
continuous = ['SalePrice', 'TotalBsmtSF', 'GrLivArea']

for feature in continuous:
    sns.distplot(train[feature], fit=norm)
    plt.show()

# %%
train[features].head()

# %%
combined_data = pd.concat((train, test)).reset_index(drop=True)

# %%
feature_dataset = combined_data[features]
feature_dataset = feature_dataset.drop('SalePrice', axis=1)
feature_dataset

# %%
#x_train = feature_dataset.drop('SalePrice', axis=1)

# %%
#x_train.head()

# %%
#y_train = feature_dataset[['SalePrice']]

# %%
#y_train

# %%
#features_testset = test[x_train.columns]
#features_testset

# %%
#x_test = features_testset
x_test.head()

# %%
#x_test.isna().sum()

# %%
#x_test = x_test[x_test.columns].dropna(axis=0)
#x_test.shape

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(feature_dataset,target_feature,test_size=0.5,random_state=0)

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)

# %%
y_pred = lr.predict(x_test)
y_pred[:10]

# %%
print('R squared score',metrics.r2_score(y_test,y_pred))
print('\nMean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %%
x_train.shape, x_test.shape
